# %%
# %pip install torch torchvision pandas matplotlib seaborn scikit-image
# Out:
# Requirement already satisfied: torch in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (2.5.1)
# Requirement already satisfied: torchvision in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (0.20.1)
# Requirement already satisfied: pandas in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: matplotlib in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: seaborn in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (0.12.2)
# Requirement already satisfied: scikit-image in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (0.25.0)
# Requirement already satisfied: filelock in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from torch) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from torchvision) (2.2.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from torchvision) (11.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: scipy>=1.11.2 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from scikit-image) (1.14.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from scikit-image) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from scikit-image) (2024.12.12)
# Requirement already satisfied: lazy-loader>=0.4 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from scikit-image) (0.4)
# Requirement already satisfied: six>=1.5 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import libraries
import torch
import torchvision
from torchvision import datasets, transforms
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from PIL import Image
import numpy as np

# For image quality assessment
from skimage import filters

# Set visual style for seaborn
sns.set(style="whitegrid")

# Set random seeds for reproducibility
import random
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

# Display inline plots
# %matplotlib inline
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_203812/2789387848.py", line 6, in <module>
#     import matplotlib.pyplot as plt
#   File "/home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/matplotlib/__init__.py", line 129, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "/home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/matplotlib/rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "/home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/matplotlib/colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "/home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/matplotlib/scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "/home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/matplotlib/ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "/home/fabi/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/matplotlib/transforms.py", line 49, in <module>
#     from matplotlib._path import (
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 6
#       4 from torchvision import datasets, transforms
#       5 import pandas as pd
# ----> 6 import matplotlib.pyplot as plt
#       7 import seaborn as sns
#       8 import os
#
# File ~/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/matplotlib/__init__.py:129
#     125 from packaging.version import parse as parse_version
#     127 # cbook must import matplotlib only within function
#     128 # definitions, so it is safe to import from it here.
# --> 129 from . import _api, _version, cbook, _docstring, rcsetup
#     130 from matplotlib.cbook import sanitize_sequence
#     131 from matplotlib._api import MatplotlibDeprecationWarning
#
# File ~/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/matplotlib/rcsetup.py:27
#      25 from matplotlib import _api, cbook
#      26 from matplotlib.cbook import ls_mapper
# ---> 27 from matplotlib.colors import Colormap, is_color_like
#      28 from matplotlib._fontconfig_pattern import parse_fontconfig_pattern
#      29 from matplotlib._enums import JoinStyle, CapStyle
#
# File ~/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/matplotlib/colors.py:56
#      54 import matplotlib as mpl
#      55 import numpy as np
# ---> 56 from matplotlib import _api, _cm, cbook, scale
#      57 from ._color_data import BASE_COLORS, TABLEAU_COLORS, CSS4_COLORS, XKCD_COLORS
#      60 class _ColorMapping(dict):
#
# File ~/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/matplotlib/scale.py:22
#      20 import matplotlib as mpl
#      21 from matplotlib import _api, _docstring
# ---> 22 from matplotlib.ticker import (
#      23     NullFormatter, ScalarFormatter, LogFormatterSciNotation, LogitFormatter,
#      24     NullLocator, LogLocator, AutoLocator, AutoMinorLocator,
#      25     SymmetricalLogLocator, AsinhLocator, LogitLocator)
#      26 from matplotlib.transforms import Transform, IdentityTransform
#      29 class ScaleBase:
#
# File ~/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/matplotlib/ticker.py:138
#     136 import matplotlib as mpl
#     137 from matplotlib import _api, cbook
# --> 138 from matplotlib import transforms as mtransforms
#     140 _log = logging.getLogger(__name__)
#     142 __all__ = ('TickHelper', 'Formatter', 'FixedFormatter',
#     143            'NullFormatter', 'FuncFormatter', 'FormatStrFormatter',
#     144            'StrMethodFormatter', 'ScalarFormatter', 'LogFormatter',
#    (...)
#     150            'MultipleLocator', 'MaxNLocator', 'AutoMinorLocator',
#     151            'SymmetricalLogLocator', 'AsinhLocator', 'LogitLocator')
#
# File ~/work/distributed-ml-stanford-cars/.venv/lib/python3.11/site-packages/matplotlib/transforms.py:49
#      46 from numpy.linalg import inv
#      48 from matplotlib import _api
# ---> 49 from matplotlib._path import (
#      50     affine_transform, count_bboxes_overlapping_bbox, update_path_extents)
#      51 from .path import Path
#      53 DEBUG = False
#
# ImportError: numpy.core.multiarray failed to import
